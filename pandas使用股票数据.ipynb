# %% [markdown]
# #### 在本地装载 Google 云端硬盘

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
import pathlib  
import pandas as pd



DATA_PATH = '/content/drive/My Drive/data/tuShare'
PROJECT_PATH = '/content/drive/My Drive/jupyter/quant/quant-learn'
# %cd {PROJECT_PATH}
# %pwd
# Out:
# /content/drive/My Drive/jupyter/quant/quant-learn
# '/content/drive/My Drive/jupyter/quant/quant-learn'

# %%
DATA_PATH
# Out:
# '/content/drive/My Drive/data/tuShare'

# %%
data_root = pathlib.Path(DATA_PATH)/'daily'
print(data_root)

all_daily = [x.name[:-4] for x in data_root.iterdir()]
#all_daily =  list(data_root.glob('*.csv'))
all_daily
# Out:
# /content/drive/My Drive/data/tuShare/daily
# ['600689.SH',
#  '600690.SH',
#  '600691.SH',
#  '600692.SH',
#  '600693.SH',
#  '600694.SH',
#  '600695.SH',
#  '600696.SH',
#  '600697.SH',
#  '600698.SH',
#  '600699.SH',
#  '600701.SH',
#  '600702.SH',
#  '600703.SH',
#  '600704.SH',
#  '600705.SH',
#  '600706.SH',
#  '600707.SH',
#  '600708.SH',
#  '600710.SH',
#  '600711.SH',
#  '600712.SH',
#  '600713.SH',
#  '600714.SH',
#  '600715.SH',
#  '600716.SH',
#  '600717.SH',
#  '600718.SH',
#  '600719.SH',
#  '600720.SH',
#  '600721.SH',
#  '600722.SH',
#  '600723.SH',
#  '600724.SH',
#  '600725.SH',
#  '600726.SH',
#  '600727.SH',
#  '600728.SH',
#  '600729.SH',
#  '600730.SH',
#  '600731.SH',
#  '600732.SH',
#  '600733.SH',
#  '600734.SH',
#  '600735.SH',
#  '600736.SH',
#  '600737.SH',
#  '600738.SH',
#  '600739.SH',
#  '600740.SH',
#  '600741.SH',
#  '600742.SH',
#  '600743.SH',
#  '600744.SH',
#  '600745.SH',
#  '600746.SH',
#  '600748.SH',
#  '600749.SH',
#  '600750.SH',
# ...

# %%
import pandas as pd
daily = pd.read_csv(all_daily[1], index_col='trade_date')

daily
# Out:
#               ts_code   open   high  ...  pct_chg        vol       amount
# trade_date                           ...
# 20191231    600690.SH  19.30  19.63  ...   0.9839  332775.02   647766.013
# 20191230    600690.SH  19.37  19.53  ...  -0.7198  451335.26   874348.962
# 20191227    600690.SH  19.83  19.96  ...  -2.2613  517746.77  1017163.890
# 20191226    600690.SH  19.16  19.98  ...   4.0795  489648.23   963571.298
# 20191225    600690.SH  19.43  19.54  ...  -1.4941  361576.02   697294.865
# ...               ...    ...    ...  ...      ...        ...          ...
# 20021203    600690.SH   9.83  10.00  ...   1.5300    6586.00     6532.952
# 20021202    600690.SH  10.16  10.16  ...  -3.3500    8094.52     8049.072
# 20021129    600690.SH  10.13  10.29  ...   0.8900   16263.92    16586.618
# 20021128    600690.SH   9.80  10.08  ...   2.8600    7496.85     7417.200
# 20021127    600690.SH   9.77   9.84  ...  -0.1000   11411.25    11077.499
#
# [4000 rows x 10 columns]

# %%
daily.plot(figsize=(12,6.5))

# %%
daily['close'].plot(figsize=(16,7))

# %%
daily[['open','high','low','close']].plot(figsize=(16,7))

# %%
pd.set_option('display.max_rows',None)
#daily[:20][['open','high','low','close']].plot(figsize=(16,6))
daily[:10]['open'].plot(figsize=(16,6))

# %%
daily[:20][['open','high','low','close']][20191231:20191230]
# Out:
# Empty DataFrame
# Columns: [open, high, low, close]
# Index: []

# %%
daily.shape
# Out:
# (4000, 10)

# %% [markdown]
# 统计所有股票有的数据量

# %%
ts_code_rows_array = []
for ts_code in all_daily:
  #print(ts_code.name[:-4])
  d = pd.read_csv(ts_code, index_col='trade_date')
  #print(d.shape[0])
  ts_code_rows_array.append([ts_code.name[:-4],d.shape[0]])
  #break

#ts_code_rows_array
# Out:
# [['600689.SH', 4000],
#  ['600690.SH', 4000],
#  ['600691.SH', 4000],
#  ['600692.SH', 4000],
#  ['600693.SH', 4000],
#  ['600694.SH', 4000],
#  ['600695.SH', 4000],
#  ['600696.SH', 4000],
#  ['600697.SH', 4000],
#  ['600698.SH', 4000],
#  ['600699.SH', 4000],
#  ['600701.SH', 4000],
#  ['600702.SH', 4000],
#  ['600703.SH', 4000],
#  ['600704.SH', 4000],
#  ['600705.SH', 3891],
#  ['600706.SH', 4000],
#  ['600707.SH', 4000],
#  ['600708.SH', 4000],
#  ['600710.SH', 4000],
#  ['600711.SH', 4000],
#  ['600712.SH', 4000],
#  ['600713.SH', 4000],
#  ['600714.SH', 4000],
#  ['600715.SH', 4000],
#  ['600716.SH', 4000],
#  ['600717.SH', 4000],
#  ['600718.SH', 4000],
#  ['600719.SH', 4000],
#  ['600720.SH', 4000],
#  ['600721.SH', 4000],
#  ['600722.SH', 4000],
#  ['600723.SH', 4000],
#  ['600724.SH', 4000],
#  ['600725.SH', 4000],
#  ['600726.SH', 4000],
#  ['600727.SH', 4000],
#  ['600728.SH', 4000],
#  ['600729.SH', 4000],
#  ['600730.SH', 4000],
#  ['600731.SH', 4000],
# ...

# %% [markdown]
# 将股票统计数据写入表中

# %%
ts_code_rows = pd.DataFrame(ts_code_rows_array, columns=['ts_code','rows'])
ts_code_rows.to_csv(DATA_PATH+'/ts_code_rows.csv',index=False)
ts_code_rows
# Out:
#         ts_code  rows
# 0     600689.SH  4000
# 1     600690.SH  4000
# 2     600691.SH  4000
# 3     600692.SH  4000
# 4     600693.SH  4000
# ...         ...   ...
# 3749  002296.SZ  2345
# 3750  002297.SZ  2246
# 3751  002298.SZ  2337
# 3752  002299.SZ  2356
# 3753  002300.SZ  2473
#
# [3754 rows x 2 columns]

# %%
#ts_code_rows = ts_code_rows.set_index('ts_code')
ts2 = ts_code_rows.sort_values(by='rows')
#ts_code_rows.plot(figsize=(16,7))
ts2.head(10)
# Out:
#         ts_code  rows
# 976   688181.SH     0
# 2645  002973.SZ     0
# 959   688081.SH     0
# 512   603109.SH     1
# 958   688078.SH     2
# 1434  300811.SZ     2
# 2644  002972.SZ     3
# 984   688268.SH     4
# 923   603995.SH     6
# 970   688123.SH     7

# %%
for index,rows in ts2.iterrows():
  print(index,rows['rows'])
  #break
# Out:
# 688181.SH 0
# 002973.SZ 0
# 688081.SH 0
# 603109.SH 1
# 688078.SH 2
# 300811.SZ 2
# 002972.SZ 3
# 688268.SH 4
# 603995.SH 6
# 688123.SH 7
# 601512.SH 8
# 688089.SH 9
# 300807.SZ 9
# 002970.SZ 11
# 603053.SH 11
# 001914.SZ 12
# 688037.SH 12
# 688039.SH 15
# 688218.SH 15
# 601658.SH 16
# 688198.SH 17
# 688258.SH 17
# 300810.SZ 18
# 688399.SH 19
# 300809.SZ 20
# 688118.SH 20
# 688357.SH 20
# 002968.SZ 21
# 688310.SH 21
# 688358.SH 21
# 002969.SZ 22
# 300808.SZ 23
# 300801.SZ 24
# 601916.SH 26
# 300806.SZ 27
# 603390.SH 27
# 300798.SZ 28
# 688196.SH 29
# 300805.SZ 29
# 688138.SH 30
# 300803.SZ 32
# 688111.SH 32
# 300796.SZ 33
# 688101.SH 33
# 688300.SH 33
# 300802.SZ 34
# 603489.SH 37
# 002967.SZ 38
# 300564.SZ 38
# 688166.SH 38
# 688363.SH 40
# 688021.SH 40
# 300800.SZ 40
# 688288.SH 40
# 688299.SH 40
# 688202.SH 41
# 688199.SH 41
# 688389.SH 41
# 688023.SH 41
# 688128.SH 41
# 300797.SZ 43
# 688058.SH 43
# 688025.SH 44
# 688369.SH 44
# 688366.SH 45
# 688108.SH 45
# 603610.SH 46
# ...

# %% [markdown]
# 读股票统计数据

# %%
ts_code_rows = pd.read_csv(DATA_PATH+'/ts_code_rows.csv')
ts_code_rows[ts_code_rows.rows > 2000].sort_values(by='rows')
# Out:
#         ts_code  rows
# 2822  300179.SZ  2001
# 411   601908.SH  2002
# 404   601886.SH  2002
# 2795  300152.SZ  2002
# 2900  300259.SZ  2003
# 2793  300150.SZ  2004
# 2211  002513.SZ  2005
# 2865  300224.SZ  2005
# 2905  300264.SZ  2005
# 2314  002618.SZ  2005
# 2896  300255.SZ  2006
# 2257  002560.SZ  2006
# 2825  300182.SZ  2007
# 2267  002570.SZ  2007
# 383   601798.SH  2007
# 2141  002442.SZ  2007
# 2311  002615.SZ  2008
# 2261  002564.SZ  2011
# 2241  002544.SZ  2011
# 369   601677.SH  2011
# 2783  300140.SZ  2013
# 2305  002609.SZ  2013
# 2184  002486.SZ  2014
# 2862  300221.SZ  2014
# 278   601113.SH  2016
# 2744  300100.SZ  2017
# 2869  300228.SZ  2017
# 2309  002613.SZ  2018
# 2805  300162.SZ  2021
# 341   601519.SH  2021
# 2819  300176.SZ  2022
# 2078  002379.SZ  2022
# 2205  002507.SZ  2024
# 307   601222.SH  2026
# 2227  002530.SZ  2026
# 345   601567.SH  2027
# 364   601636.SH  2027
# 2899  300258.SZ  2028
# 2110  002411.SZ  2028
# 2683  300038.SZ  2028
# ...

# %% [markdown]
# 将多个股票的数据合并到一个csv中

# %%
childrens = [x for x in data_root.iterdir()]
ch1 = pd.read_csv(childrens[0])
all_code_path = DATA_PATH+'/ts_all_code.csv'
ch1.to_csv(all_code_path,index=False)

for p in childrens[1:]:
  ch2 = pd.read_csv(p)
  ch2.to_csv(all_code_path,index=False, header=False, mode='a+')

# %%
all_code_path = DATA_PATH+'/ts_all_code.csv'
all_code = pd.read_csv(all_code_path)
all_code
# Out:
#            ts_code  trade_date   open  ...  pct_chg        vol       amount
# 0        600689.SH    20191231   9.64  ...   1.4493   38844.72   38199.8350
# 1        600689.SH    20191230   9.52  ...   0.9404   17645.70   16899.2070
# 2        600689.SH    20191227   9.68  ...  -0.4162   12860.69   12367.0350
# 3        600689.SH    20191226   9.56  ...   0.7338   10453.60   10036.3080
# 4        600689.SH    20191225   9.52  ...   0.2101   12995.01   12426.9580
# ...            ...         ...    ...  ...      ...        ...          ...
# 8540540  002300.SZ    20091027  36.81  ...  -4.8800   53722.82  193437.4905
# 8540541  002300.SZ    20091026  38.95  ...  -3.8900   59942.11  226241.0240
# 8540542  002300.SZ    20091023  38.50  ...  -2.5800  110044.90  426429.0459
# 8540543  002300.SZ    20091022  35.92  ...   5.7000  162351.35  614864.7354
# 8540544  002300.SZ    20091021  32.50  ...  83.4100  224820.94  794854.1008
#
# [8540545 rows x 11 columns]

# %%
all_code.groupby('ts_code').size()
# Out:
# ts_code
# 000001.SZ    4000
# 000002.SZ    4000
# 000004.SZ    4000
# 000005.SZ    4000
# 000006.SZ    4000
#              ...
# 688368.SH      57
# 688369.SH      44
# 688388.SH     111
# 688389.SH      41
# 688399.SH      19
# Length: 3751, dtype: int64

# %%
import numpy as np

tm_code = all_code.groupby('ts_code').size()

have_code = np.array(tm_code.index)
real_have_code = np.array(all_daily)
have_code.shape,real_have_code.shape
# Out:
# ((3751,), (3754,))

# %% [markdown]
# 检查两个np数组的差别

# %%
diff1d_code = np.setdiff1d(real_have_code,have_code)
diff1d_code
# Out:
# array(['002973.SZ', '688081.SH', '688181.SH'], dtype='<U9')

# %%
df1 = pd.read_csv(data_root/(diff1d_code[0]+'.csv'))
df1
# Out:
# Empty DataFrame
# Columns: [ts_code, trade_date, open, high, low, close, pre_close, change, pct_chg, vol, amount]
# Index: []

# %%
for k in diff1d_code:
  df1 = pd.read_csv(data_root/(k+'.csv'))
  df1.to_csv(DATA_PATH+'/ts_all_code.csv',index=False, header=False, mode='a+')

# %% [markdown]
# 转换日期和代码列为索引

# %%
ts_code = all_code.set_index(['ts_code',	'trade_date'])
ts_code
# Out:
#                        open   high    low  ...  pct_chg        vol       amount
# ts_code   trade_date                       ...
# 600689.SH 20191231     9.64   9.97   9.63  ...   1.4493   38844.72   38199.8350
#           20191230     9.52   9.68   9.41  ...   0.9404   17645.70   16899.2070
#           20191227     9.68   9.68   9.56  ...  -0.4162   12860.69   12367.0350
#           20191226     9.56   9.65   9.55  ...   0.7338   10453.60   10036.3080
#           20191225     9.52   9.63   9.48  ...   0.2101   12995.01   12426.9580
# ...                     ...    ...    ...  ...      ...        ...          ...
# 002300.SZ 20091027    36.81  36.81  35.38  ...  -4.8800   53722.82  193437.4905
#           20091026    38.95  39.02  37.10  ...  -3.8900   59942.11  226241.0240
#           20091023    38.50  39.80  38.02  ...  -2.5800  110044.90  426429.0459
#           20091022    35.92  40.79  35.30  ...   5.7000  162351.35  614864.7354
# ...

# %%
ts_code.shape
# Out:
# (8540545, 9)

# %%
ts_code.describe()
# Out:
#                open          high  ...           vol        amount
# count  8.540545e+06  8.540545e+06  ...  8.540545e+06  8.540545e+06
# mean   1.460335e+01  1.493793e+01  ...  1.068875e+05  1.271433e+05
# std    1.613283e+01  1.653170e+01  ...  3.078312e+05  3.398206e+05
# min    2.400000e-01  2.500000e-01  ...  1.000000e+00  4.320000e-01
# 25%    6.430000e+00  6.560000e+00  ...  1.572326e+04  1.610754e+04
# 50%    1.028000e+01  1.049000e+01  ...  4.078074e+04  4.558141e+04
# 75%    1.721000e+01  1.759000e+01  ...  1.017353e+05  1.205481e+05
# max    1.231000e+03  1.241610e+03  ...  5.135467e+07  6.999139e+07
#
# [8 rows x 9 columns]

# %%
all_code.describe()
# Out:
#          trade_date          open  ...           vol        amount
# count  8.540545e+06  8.540545e+06  ...  8.540545e+06  8.540545e+06
# mean   2.012679e+07  1.460335e+01  ...  1.068875e+05  1.271433e+05
# std    4.918318e+04  1.613283e+01  ...  3.078312e+05  3.398206e+05
# min    1.998010e+07  2.400000e-01  ...  1.000000e+00  4.320000e-01
# 25%    2.009072e+07  6.430000e+00  ...  1.572326e+04  1.610754e+04
# 50%    2.013112e+07  1.028000e+01  ...  4.078074e+04  4.558141e+04
# 75%    2.017061e+07  1.721000e+01  ...  1.017353e+05  1.205481e+05
# max    2.019123e+07  1.231000e+03  ...  5.135467e+07  6.999139e+07
#
# [8 rows x 10 columns]

# %%
ts_code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8540545 entries, (600689.SH, 20191231) to (002300.SZ, 20091021)
# Data columns (total 9 columns):
# open         float64
# high         float64
# low          float64
# close        float64
# pre_close    float64
# change       float64
# pct_chg      float64
# vol          float64
# amount       float64
# dtypes: float64(9)
# memory usage: 619.2+ MB

# %%
import matplotlib.pyplot as plt
ts_code.hist(bins=5,figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4e6ca92d30>,
# ...
#       dtype=object)

# %% [markdown]
# ###数据标准化
#
# 将取值范围差异很大的数据输入到神经网络中，这是有问题的。网络可能会自动适应这种 取值范围不同的数据，但学习肯定变得更加困难。对于这种数据，普遍采用的最佳实践是对每 个特征做标准化，即对于输入数据的每个特征(输入数据矩阵中的列)，减去特征平均值，再除 7 以标准差，这样得到的特征平均值为 0，标准差为 1。用 Numpy 可以很容易实现标准化。

# %%
mean = ts_code.mean(axis=0) 
ts_code -= mean
std = ts_code.std(axis=0) 
ts_code /= std

ts_code
# Out:
#                           open      high  ...       vol    amount
# ts_code   trade_date                      ...
# 600689.SH 20191231   -0.307655 -0.300509  ... -0.221039 -0.261736
#           20191230   -0.315094 -0.318051  ... -0.289905 -0.324418
#           20191227   -0.305176 -0.318051  ... -0.305449 -0.337755
#           20191226   -0.312614 -0.319866  ... -0.313269 -0.344614
#           20191225   -0.315094 -0.321076  ... -0.305013 -0.337579
# ...                        ...       ...  ...       ...       ...
# 002300.SZ 20091027    1.376488  1.323038  ... -0.172707  0.195086
#           20091026    1.509137  1.456721  ... -0.152504  0.291618
#           20091023    1.481243  1.503903  ...  0.010257  0.880717
#           20091022    1.321321  1.563788  ...  0.180176  1.435232
#           20091021    1.109331  1.425266  ...  0.383111  1.964892
#
# [8540545 rows x 9 columns]
