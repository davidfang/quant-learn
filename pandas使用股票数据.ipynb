# %% [markdown]
# #### 在本地装载 Google 云端硬盘

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
import pathlib  


DATA_PATH = '/content/drive/My Drive/data/tuShare'
PROJECT_PATH = '/content/drive/My Drive/jupyter/quant/quant-learn'
# %cd {PROJECT_PATH}
# %pwd
# Out:
# /content/drive/My Drive/jupyter/quant/quant-learn
# '/content/drive/My Drive/jupyter/quant/quant-learn'

# %%
DATA_PATH
# Out:
# '/content/drive/My Drive/data/tuShare'

# %%
data_root = pathlib.Path(DATA_PATH)/'daily'
print(data_root)

all_daily =  list(data_root.glob('*.csv'))
#all_daily
# Out:
# /content/drive/My Drive/data/tuShare/daily

# %%
import pandas as pd
daily = pd.read_csv(all_daily[0], index_col='trade_date')

daily
# Out:
#               ts_code   open   high  ...  pct_chg       vol     amount
# trade_date                           ...
# 20191231    600689.SH   9.64   9.97  ...   1.4493  38844.72  38199.835
# 20191230    600689.SH   9.52   9.68  ...   0.9404  17645.70  16899.207
# 20191227    600689.SH   9.68   9.68  ...  -0.4162  12860.69  12367.035
# 20191226    600689.SH   9.56   9.65  ...   0.7338  10453.60  10036.308
# 20191225    600689.SH   9.52   9.63  ...   0.2101  12995.01  12426.958
# ...               ...    ...    ...  ...      ...       ...        ...
# 20020802    600689.SH  10.68  10.75  ...   0.0900   1308.53   1399.025
# 20020801    600689.SH  10.74  10.80  ...  -0.4700   1711.01   1828.389
# 20020731    600689.SH  10.83  10.89  ...  -0.9200   2300.58   2477.650
# 20020730    600689.SH  10.84  10.89  ...   0.0000   1782.28   1922.997
# 20020729    600689.SH  10.87  10.87  ...  -0.6400   3081.58   3320.278
#
# [4000 rows x 10 columns]

# %%
daily.plot(figsize=(12,6.5))

# %%
daily['close'].plot(figsize=(16,7))

# %%
daily[['open','high','low','close']].plot(figsize=(16,7))

# %%
pd.set_option('display.max_rows',None)
#daily[:20][['open','high','low','close']].plot(figsize=(16,6))
daily[:10]['open'].plot(figsize=(16,6))

# %%
daily[:20][['open','high','low','close']][20191231:20191230]
# Out:
# Empty DataFrame
# Columns: [open, high, low, close]
# Index: []
