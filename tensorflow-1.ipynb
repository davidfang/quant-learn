# %% [markdown]
# ### 在本地装载 Google 云端硬盘

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
import pathlib
import pandas as pd
  


DATA_PATH = pathlib.Path('/content/drive/My Drive/data/tuShare')
PROJECT_PATH = pathlib.Path('/content/drive/My Drive/jupyter/quant/quant-learn')
# %cd {PROJECT_PATH}
# %pwd
# Out:
# /content/drive/My Drive/jupyter/quant/quant-learn
# '/content/drive/My Drive/jupyter/quant/quant-learn'

# %% [markdown]
# ### 获取标准化数据
#
# 统一使用2000行以上的数据,先查看一下数据结构：

# %%
ts_code_row = ts_code_rows[ts_code_rows.rows > 2000].sort_values(by='rows').iat[0,0]+'.csv'
daily = pd.read_csv(DATA_PATH/'daily'/ts_code_row)
daily
# Out:
#         ts_code  trade_date   open  ...  pct_chg        vol       amount
# 0     300179.SZ    20191231   5.95  ...   0.5025   81467.93   48673.9610
# 1     300179.SZ    20191230   6.10  ...  -1.8092  123040.48   73139.4590
# 2     300179.SZ    20191227   6.19  ...  -3.0303  179594.62  110664.6640
# 3     300179.SZ    20191226   6.05  ...   1.4563  224255.63  137180.5690
# 4     300179.SZ    20191225   6.05  ...   0.4878  396884.73  243829.0820
# ...         ...         ...    ...  ...      ...        ...          ...
# 1996  300179.SZ    20110221  33.11  ...  -2.1900   51825.65  172890.2578
# 1997  300179.SZ    20110218  31.79  ...   9.3800   91773.55  307007.4857
# 1998  300179.SZ    20110217  31.85  ...  -1.2300   54895.13  175134.7766
# 1999  300179.SZ    20110216  31.80  ...  -3.0500   78063.86  246173.7632
# 2000  300179.SZ    20110215  30.60  ...  32.3200  139428.88  440780.1940
#
# [2001 rows x 11 columns]

# %%
ts_code_rows = pd.read_csv(DATA_PATH/'ts_code_rows.csv')
for index,value in ts_code_rows[ts_code_rows.rows > 2000].sort_values(by='rows').iterrows():
  print(value['ts_code'],value['rows'])
  csv = value['ts_code']+'.csv'
  daily = pd.read_csv(DATA_PATH/'daily'/csv)
  print(daily.columns)
  break
# Out:
# 300179.SZ 2001
# Index(['ts_code', 'trade_date', 'open', 'high', 'low', 'close', 'pre_close',
#        'change', 'pct_chg', 'vol', 'amount'],
#       dtype='object')
